# %%
import json
import os
import pandas as pd
import numpy as np

# %%
path = "../data/2023-04-14-job-search-location-DC"
file_names = os.listdir(path)

df_list = []

for name in file_names:
    file_path = os.path.join(path, name)
    json_file = json.load(open(file_path))
    if 'jobs_results' in json_file:
        df_json = pd.DataFrame(json_file['jobs_results'])
        df_json['search'] = name.split(".")[0]
        df_json['search_location'] = 'DC'
        df_list.append(df_json)

df_dc = pd.concat(df_list, ignore_index=True)

# %%
df_highlights = df_dc['job_highlights'].apply(pd.Series)
df_highlights.columns = ['Qualifications', 'Responsibilities', 'Benefits']

df_highlights = df_highlights.applymap(lambda x: x.get('items') if isinstance(x, dict) else ["None"])
df_highlights = df_highlights.applymap(lambda x: ''.join(x))

df_dc_1 = pd.concat([df_dc, df_highlights], axis=1)

df_dc_1['wfh'] = df_dc['detected_extensions'].apply(lambda x: x.get('work_from_home') == True)
df_dc_1['schedule_type'] = df_dc['detected_extensions'].apply(lambda x: x.get('schedule_type'))

# %%
path = "../data/2023-04-14-job-search-location-USA"
file_names = os.listdir(path)

df_list = []

for name in file_names:
    file_path = os.path.join(path, name)
    json_file = json.load(open(file_path))
    if 'jobs_results' in json_file:
        df_json = pd.DataFrame(json_file['jobs_results'])
        df_json['search'] = name.split(".")[0]
        df_json['search_location'] = 'USA'
        df_list.append(df_json)

df_usa = pd.concat(df_list, ignore_index=True)

# %%
df_highlights = df_usa['job_highlights'].apply(pd.Series)
df_highlights.columns = ['Qualifications', 'Responsibilities', 'Benefits']

df_highlights = df_highlights.applymap(lambda x: x.get('items') if isinstance(x, dict) else ["None"])
df_highlights = df_highlights.applymap(lambda x: ''.join(x))

df_usa_1 = pd.concat([df_usa, df_highlights], axis=1)

df_usa_1['wfh'] = df_usa_1['detected_extensions'].apply(lambda x: x.get('work_from_home') == True)
df_usa_1['schedule_type'] = df_usa_1['detected_extensions'].apply(lambda x: x.get('schedule_type'))

# %%
df_usa_1
# Out:
#                                                  title       company_name  \
# 0                  Senior Blockchain Software Engineer             Truist
# 1    Get twitter accounts that are tied to blockcha...             Upwork
# 2                                   Blockchain Analyst             Allium
# 3                       Full Stack Blockchain Engineer             geojam
# 4    Blockchain Engineer - Apps Platform at Exodus ...             Exodus
# ..                                                 ...                ...
# 452  Machine Learning Engineer/ Data Scientist- NLP...          Supportiv
# 453  Post-Doc Researcher for Natural Language Proce...       Robert Bosch
# 454  Technical Leader - Natural Language Processing...            Kitware
# 455  Lead Research Scientist, Natural Language Proc...          Snap Inc.
# 456  Research Associate  in Natural Language Proces...  SRI International
#
#                  location                        via  \
# 0               Anywhere            via ZipRecruiter
# 1               Anywhere                  via Upwork
# 2         New York, NY                      via Jobs
# 3      Los Angeles, CA                 via AngelList
# 4        Livermore, CA     via Livermore, CA - Geebo
# ..                    ...                        ...
# 452        Chicago, IL                 via KLFY Jobs
# 453      Sunnyvale, CA                   via Ladders
# 454    Minneapolis, MN              via ZipRecruiter
# 455    Los Angeles, CA                    via Jooble
# 456     Menlo Park, CA                  via Snagajob
#
#                                            description  \
# 0    The position is described below. If you want t...
# 1    I am looking for a list of blockchain addresse...
# 2    About the role\n• Sherlock & Enola Holmes leve...
# 3    Who We Are\n\nLaunched in 2020, Geojam is a so...
# 4    Exodus is looking for a detail-orientated Bloc...
# ..                                                 ...
# 452  First, The Data!\n• Over 1 million unique chat...
# 453  Company Description\n\nThe Bosch Research and ...
# 454  Team Description:\n\nOur computer vision team ...
# 455  Lead Research Scientist, Natural Language Proc...
# 456  Research Associate in Natural Language Process...
#
#                                         job_highlights  \
# 0    [{'title': 'Qualifications', 'items': ['Langua...
# 1    [{'items': ['I am looking for a list of blockc...
# 2    [{'title': 'Qualifications', 'items': ['Abilit...
# 3    [{'title': 'Qualifications', 'items': ['We’re ...
# 4    [{'items': ['Exodus is looking for a detail-or...
# ..                                                 ...
# 452  [{'title': 'Qualifications', 'items': ['[1 day...
# 453  [{'title': 'Qualifications', 'items': ['Ph.D. ...
# 454  [{'title': 'Qualifications', 'items': ['PhD in...
# 455  [{'title': 'Qualifications', 'items': ['Strong...
# 456  [{'title': 'Qualifications', 'items': ['We are...
#
#                                          related_links  \
# 0    [{'link': 'http://www.truist.com/', 'text': 't...
# 1    [{'link': 'http://www.elance.com/', 'text': 'e...
# 2    [{'link': 'https://www.google.com/search?ucbcb...
# 3    [{'link': 'https://www.google.com/search?ucbcb...
# 4    [{'link': 'https://www.google.com/search?ucbcb...
# ..                                                 ...
# 452  [{'link': 'https://www.google.com/search?hl=en...
# 453  [{'link': 'http://www.bosch.com/', 'text': 'bo...
# 454  [{'link': 'http://www.kitware.com/', 'text': '...
# 455  [{'link': 'http://www.snap.com/', 'text': 'sna...
# 456  [{'link': 'http://www.sri.com/', 'text': 'sri....
#
#                                             extensions  \
# 0    [7 days ago, Work from home, Full-time, Health...
# 1             [4 days ago, Work from home, Contractor]
# 2    [Full-time, No degree mentioned, Health insura...
# 3    [Full-time, No degree mentioned, Health insura...
# 4    [2 days ago, 20–28 an hour, Full-time, No degr...
# ..                                                 ...
# 452                           [4 days ago, Internship]
# 453  [100K–150K a year, Full-time, Health insurance...
# 454  [Full-time, Health insurance, Dental insurance...
# 455          [2 days ago, Full-time, Health insurance]
# 456          [7 days ago, Full-time, Health insurance]
#
#                                    detected_extensions  \
# 0    {'posted_at': '7 days ago', 'schedule_type': '...
# 1    {'posted_at': '4 days ago', 'schedule_type': '...
# 2                       {'schedule_type': 'Full-time'}
# 3                       {'schedule_type': 'Full-time'}
# 4    {'posted_at': '2 days ago', 'schedule_type': '...
# ..                                                 ...
# 452  {'posted_at': '4 days ago', 'schedule_type': '...
# 453  {'schedule_type': 'Full-time', 'salary': '100K...
# 454                     {'schedule_type': 'Full-time'}
# 455  {'posted_at': '2 days ago', 'schedule_type': '...
# 456  {'posted_at': '7 days ago', 'schedule_type': '...
#
#                                                 job_id  \
# 0    eyJqb2JfdGl0bGUiOiJTZW5pb3IgQmxvY2tjaGFpbiBTb2...
# 1    eyJqb2JfdGl0bGUiOiJHZXQgdHdpdHRlciBhY2NvdW50cy...
# 2    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEFuYWx5c3QiLC...
# 3    eyJqb2JfdGl0bGUiOiJGdWxsIFN0YWNrIEJsb2NrY2hhaW...
# 4    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIC...
# ..                                                 ...
# 452  eyJqb2JfdGl0bGUiOiJNYWNoaW5lIExlYXJuaW5nIEVuZ2...
# 453  eyJqb2JfdGl0bGUiOiJQb3N0LURvYyBSZXNlYXJjaGVyIG...
# 454  eyJqb2JfdGl0bGUiOiJUZWNobmljYWwgTGVhZGVyIC0gTm...
# 455  eyJqb2JfdGl0bGUiOiJMZWFkIFJlc2VhcmNoIFNjaWVudG...
# 456  eyJqb2JfdGl0bGUiOiJSZXNlYXJjaCBBc3NvY2lhdGUgIG...
#
#                             search search_location  \
# 0                    block-chain-1             USA
# 1                    block-chain-1             USA
# 2                    block-chain-1             USA
# 3                    block-chain-1             USA
# 4                    block-chain-1             USA
# ..                             ...             ...
# 452  natural-language-processing-2             USA
# 453  natural-language-processing-2             USA
# 454  natural-language-processing-2             USA
# 455  natural-language-processing-2             USA
# 456  natural-language-processing-2             USA
#
#                                         Qualifications  \
# 0    Language Fluency: English (Required)The requir...
# 1    I am looking for a list of blockchain addresse...
# 2    Ability to parse and understand EVM (and/or So...
# 3    We’re looking for a capable generalist enginee...
# 4    Exodus is looking for a detail-orientated Bloc...
# ..                                                 ...
# 452  [1 day] Take-home programming challenge[60 min...
# 453  Ph.D. in computer science or engineering3+ yea...
# 454  PhD in Computer Science or related field with ...
# 455  Strong technical knowledge of statistics, mach...
# 456  We are seeking a potential NLP thought leader ...
#
#                                       Responsibilities  \
# 0    Deliver highly complex solutions with signific...
# 1                                                 None
# 2    Tackling interesting problems - we are ingesti...
# 3    You will be designing and building our core so...
# 4                                                 None
# ..                                                 ...
# 452  The role will serve as a core member within th...
# 453  Conduct research on Natural Language Processin...
# 454  Lead proposals for new funding from government...
# 455  Define and own a roadmap of large-scale resear...
# 456  Successful applicants will work as part of a t...
#
#                                               Benefits    wfh schedule_type
# 0    General Description of Available Benefits for ...   True     Full-time
# 1                                                 None   True    Contractor
# 2    An accelerated growth trajectory - you will ha...  False     Full-time
# 3    We’re wrapping up our presale for $JAM, so you...  False     Full-time
# 4                                                 None  False     Full-time
# ..                                                 ...    ...           ...
# 452                                               None  False    Internship
# 453  The U.S. base salary range for this full-time ...  False     Full-time
# 454  Besides a great work environment, our comprehe...  False     Full-time
# 455  In the United States, work locations are assig...  False     Full-time
# 456  The salary range is: $117,545.00-$155,744.00Sa...  False     Full-time
#
# [457 rows x 17 columns]

# %%
df_all = pd.concat([df_dc_1, df_usa_1])

# %%
df_dc_1.to_csv("../data/dc_job.csv")
df_usa_1.to_csv("../data/usa_job.csv")
df_all.to_csv('../data/all_job.csv')
